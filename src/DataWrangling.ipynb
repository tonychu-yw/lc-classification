# %% [markdown]
# # Setup

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/My Drive/Github/SubjectIndexing"
# Out:
# /content/gdrive/My Drive/Github/SubjectIndexing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.preprocessing import clean_books
# Out:
#   File "/content/gdrive/My Drive/Github/SubjectIndexing/src/preprocessing.py", line 59
#     cls = metadata.subjects.apply(lambda x: class in x)
#                                                 ^
# SyntaxError: invalid syntax
