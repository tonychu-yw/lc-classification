# %% [markdown]
# # Setup

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/My Drive/Github/SubjectIndexing"
# Out:
# /content/gdrive/My Drive/Github/SubjectIndexing

# %%
import pandas as pd

# %% [markdown]
# # Data Wrangling

# %%
dataset_B = pd.read_json('./data/dataset_B.json')

# %%
dataset_B.head()
# Out:
#    index  ...                                               text
# 0     10  ...  the project gutenberg ebook of the king james ...
# 1     17  ...  the project gutenberg ebook of the book of mor...
# 2     30  ...  project gutenberg's the bible, king james vers...
# 3     59  ...  the project gutenberg ebook of a discourse on ...
# 4    124  ...  project gutenberg's deuterocanonical books of ...
#
# [5 rows x 6 columns]

# %%
window = 4096
skip = 300
X = []
y = []
for i in range(len(dataset_B)):
    tokens = ' '.join(dataset_B.text[i].split()[skip:4096+skip])
    X.append(tokens)
    temp = []
    for s in dataset_B.subjects_new[i]:
        if s in set(['B', 'BC', 'BD', 'BF', 'BH', 'BJ', 'BL', 'BM', 'BP', 'BQ', 'BR', 'BS', 'BT', 'BV', 'BX']):
            temp.append(s)
    y.append(temp)

# %%
len(X)
# Out:
# 3605

# %%
multi = []
for i in range(len(y)):
    if len(y[i]) > 1:
        multi.append(i)
        if len(y[i]) > 2:
            print(len(y[i]))

# %%
final_y = []
for i in range(len(y)):
    if i in multi:
        final_y.append(y[i][0])
        final_y.append(y[i][1])
    else:
        final_y.append(y[i][0])

final_X = []
for i in range(len(X)):
    if i in multi:
        final_X.append(X[i])
        final_X.append(X[i])
    else:
        final_X.append(X[i])

# %%
len(final_X), len(final_y)
# Out:
# (3641, 3641)

# %%
df = pd.DataFrame({'X': final_X, 'y': final_y})

# %%
df.to_json('./data/dataset_B.json')
