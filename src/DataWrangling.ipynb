# %% [markdown]
# # Setup

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/My Drive/Github/SubjectIndexing"
# Out:
# /content/gdrive/My Drive/Github/SubjectIndexing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.preprocessing import clean_books

# %% [markdown]
# # Data Wrangling

# %%
clean_books('./data/gutenberg', './data/metadata.json', './data/books')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# --- Start locating files ---
# --- Locating files complete! ---
# --- Start reading files ---
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-e2bd1d70f42f> in <module>()
# ----> 1 clean_books('./data/gutenberg', './data/metadata.json', './data/books')
#
# /content/gdrive/My Drive/Github/SubjectIndexing/src/preprocessing.py in clean_books(books_folder, metadata_dir, output_dir, lc_class, n_tokens)
#      79             if iter%100 == 0:
#      80                 end = time.time()
# ---> 81                 print(iter, " - time:", round((end-start)//60), "min",  round((end-start)%60), "sec")
#      82         end = time.time()
#      83         print("Total read time:", round((end-start)//60), "min",  round((end-start)%60), "sec")
#
# UnboundLocalError: local variable 'start' referenced before assignment
