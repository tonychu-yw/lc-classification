# %% [markdown]
# # Setup

# %%
# mount drive 
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/My Drive/Github/SubjectIndexing"
# Out:
# /content/gdrive/My Drive/Github/SubjectIndexing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from src.preprocessing import clean_books

# %% [markdown]
# # Data Wrangling

# %%
clean_books('./data/gutenberg', './data/metadata.json', './data/books')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-e2bd1d70f42f> in <module>()
# ----> 1 clean_books('./data/gutenberg', './data/metadata.json', './data/books')
#
# /content/gdrive/My Drive/Github/SubjectIndexing/src/preprocessing.py in clean_books(books_folder, metadata_dir, output_dir, lc_class)
#      62         books = []
#      63         books_idx = []
# ---> 64         list_docs = os.listdir(books_folder)
#      65         for doc in list_docs:
#      66             idx = doc.replace('-0', '').replace('-8', '')[:-4]
#
# OSError: [Errno 5] Input/output error: './data/gutenberg'
